# %%
# !pip install isodate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 460 kB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate) (1.15.0)
# Installing collected packages: isodate
# Successfully installed isodate-0.6.1

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 6.1 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)

# %%
from apiclient.discovery import build
import googleapiclient.discovery
import os
import time
import pandas as pd
from dateutil import parser
import numpy as np
from nltk.probability import FreqDist
import re, nltk
import nltk
import string
import isodate
from nltk import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()

os.environ["TZ"]="Asia/Jakarta"
time.tzset()




def preprocessing(line):
    emoji_pattern = re.compile("["
        	u"\U0001F600-\U0001F64F"  # emoticons
        	u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        	u"\U0001F680-\U0001F6FF"  # transport & map symbols
        	u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
    line=emoji_pattern.sub(r'', line) # no emoji
    line = line.upper()
    line = re.sub(r"[{}]".format(string.punctuation), " ", line)
    for stop_word in stopwords:
        line = line.replace(stop_word,' ')
        line =  re.sub(r'\b[0-9(.,)+]*\b', '', line)
    print(line)
    return line



api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDe422JDFG94LDpM60_9Ls_JbQLTmnK-ls" #ini Youtube API Key Akdeas

youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = DEVELOPER_KEY)

#masukkan channel link
channellink = "UC727SQYUvx5pDDGQpTICNWg"

#kobo: "UCjLEmnpCNeisMxy134KPwWw"
#moona: "UCP0BspO_AMEe3aQqqpo89Dg"
#ollie: "UCYz_5n-uDuChHtLo7My1HnQ"
#risu: "UCOyYb1c43VlX9rc_lT6NKQw"
#reine: "UChgTyjG-pdNvxxhdsXfHQ5Q"
#miti: "UCCK072ns5Bt1nYqX1CoaZ-g"
#andi: "UC9QnAjC7mT4ggHuedr1_kqQ"
#yopi: "UCAoy6rzhSf4ydcYjJw3WoVg"
#zeta: "UCTvHWSfBZgtxE4sILOaurIQ"
#anya: "UC727SQYUvx5pDDGQpTICNWg"

# get Uploads playlist id
def get_channel_videos(channel_id):
    
    res = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id, 
                                           part='snippet', 
                                           maxResults=50,
                                           pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
    
    return videos




#mendapatkan link video dari channel yakni video id

data=[]
videos = get_channel_videos(channellink)


for video in videos:
    title=video['snippet']['title']
    desc=video['snippet']['description']
    idv=video['snippet']['resourceId']['videoId']
    res = youtube.videos().list(id=idv, part='contentDetails').execute()
    duration = res['items'][0]['contentDetails']['duration']
    lama=isodate.parse_duration(duration)
    hari=parser.parse(video['snippet']['publishedAt']).strftime("%w")
    jam=parser.parse(video['snippet']['publishedAt']).strftime("%H")
    print(parser.parse(video['snippet']['publishedAt']))
    print(hari)
    hariku=int(hari)
    jami=int(jam)+7
    if jami > 23:
	    jami=jami-24
	    hariku=hariku+1
    if hariku > 6:
	    hariku=0


    if jami < 6 and jami > 21:
	    jami=0
    elif jami > 6 and jami < 15:
	    jami=1
    else:
	    jami=3 
    data.append([hariku,jam,jami,preprocessing(title),lama,preprocessing(desc)])

df = pd.DataFrame(data,columns=['hari', 'jam','jami', 'judul','durasi','desc'])
print(df)
nltk.download('punkt')
fdist = FreqDist(sum(df['judul'].map(word_tokenize), []))
print(fdist.most_common(10))
print(df.groupby('hari').count().max(level=0))
print(df.groupby('jam').count().max(level=0))
print(df.groupby('hari').agg('count'))
print(df.groupby('jami').agg('count'))
print(df['durasi'].mean())
df.to_csv("/data_anya.csv",mode='a', encoding='utf-8')
# Out:
# Streaming output truncated to the last 5000 lines.
# ✦ PAVOLIA REINE POV  HTTPS   WWW YOUTUBE COM WATCH V F 2JW9P1QBQ
#
#
# HORROR NIGHT WITH HOLORO    HORRORO   THINKING
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
# THUMBNAIL ART  HTTPS   TWITTER COM MREKKONEN STATUS
# HTTPS   TWITTER COM MINARI STUDIO FOR BGM S
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-24 17:25:31+00:00
# 3
# 【CRYSTAR】YOU CAN PET THE DOG IN THIS GAME【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
# 本ゲームは権利者に確認を得た上で配信・収益化を行っております。
# © FURYU CORPORATION  LICENSED TO AND PUBLISHED BY SPIKE CHUNSOFT CO   LTD
#
#
# CRYSTAR
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
# THUMBNAIL ART  HTTPS   TWITTER COM MREKKONEN STATUS
# HTTPS   TWITTER COM MINARI STUDIO FOR BGM S
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-21 16:01:40+00:00
# 0
# 【DEAD BY DAYLIGHT】HELL NIGHT MATCHING TIME AGAIN【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
# THIS GAME IS BEING STREAMED AND MONETIZED AFTER CONFIRMING WITH BEHAVIOUR INTERACTIVE INC
#
#
# DBD
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-20 08:17:35+00:00
# 6
# 【SUPAREADING】SUPAREAD   FREE TALK【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
#
# CATCHING UP TO SOME SUPAS   DONATIONS    WE GOT A LOT OF  EM COMING RIGHT UP    THANK YOU FOR ALL THE SUPPORT AS USUAL
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
# THUMBNAIL ART  HTTPS   TWITTER COM ABARA STATUS
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-19 16:45:20+00:00
# 5
# 【COLLAB】SQRL   DAGGER SOLVING YOUR LOVE PROBLEMS  NOT CLICKBAIT【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
#
# ❤LOVE PROFESSORS BACK AT IT AGAIN❤
# NOTHING CAN GO WRONG THIS TIME WITH THE WISE SQRL PROFESSOR
#  ANYA MELFISSA  LIVEISSA
#
#
#
# ✦ AYUNDA RISU TUPAISEN   HTTPS   WWW YOUTUBE COM CHANNEL UCOYYB1C43VLX9RC LT6NKQW
#
#
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-18 16:40:56+00:00
# 4
# 【RANDOM KARAOKE ZATSUDAN】SINGING FREELY 自由で歌う【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
#
# CHILL NIGHT
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
# THUMBNAIL ART  HTTPS   TWITTER COM GELE RY STATUS
# INSTRUMENTAL S  USED
# 【ピアノ伴奏】長く短い祭   椎名林檎【オフボーカル】   HTTPS   WWW YOUTUBE COM WATCH V RTPZQ512JHI
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-17 03:30:24+00:00
# 3
# 【ENDER LILIES】CONTINUING THE FUN  GRINDING  GAME EXPERIENCE 【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
# THIS GAME IS BEING STREAMED AND MONETIZED AFTER CONFIRMING WITH  © BINARY HAZE INTERACTIVE INC
#
#
# HAD TOO MUCH FUN GRINDING LAST STREAM  NOW TIME TO ACTUALLY PROGRESS THROUGH    I HOPE
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
# HTTPS   TWITTER COM MINARI STUDIO FOR BGM S
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-16 18:05:12+00:00
# 2
# 【ENDER LILIES】MILI S SONGS OSTS   GUARANTEED AMAZING EXPERIENCE【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
# THIS GAME IS BEING STREAMED AND MONETIZED AFTER CONFIRMING WITH  © BINARY HAZE INTERACTIVE INC
#
#
# LET S EXPLORE THIS BEAUTIFUL FALLEN WORLD TOGETHER   YOU  AND ME  THE GAME ITSELF LOOKS A BIT TOO HARD FOR ME  THOUGH    LOL
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-14 04:33:23+00:00
# 0
# 【FALL GUYS】FALL GUYS WITH EVERYONE 【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
# THIS GAME IS BEING STREAMED AND MONETIZED FOLLOWING THE GUIDELINES OF GHI MEDIA LLC DBA DEVOLVER DIGITAL
#
#
# EVERYONE FREE TO JOIN   PLEASE JOIN ONLY ONCE FOR EACH PERSON  THANK YOU FOR UNDERSTANDING  DIRECTIONS ON HOW TO JOIN WILL ALSO BE EXPLAINED DURING STREAM
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-13 09:48:46+00:00
# 6
# 【STIGMATIZED PROPERTY   事故物件】SEARCHING FOR THAT GOOD ENDING【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
# THIS GAME IS BEING STREAMED AND MONETIZED AFTER RECEIVING PRIOR CONSENT FROM © CHILLA S ART  LLC
#
#
# WE DIDN T MANAGE TO GET THE GOOD ENDING LAST TIME SO LET S TRY AGAIN
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-12 17:53:10+00:00
# 5
# 【WATCHALONG】ALICE IN BORDERLAND    EPISODE  【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
#
# THE TOILET ISEKAI CONTINUES  LAST PART
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-11 15:50:56+00:00
# 4
# 【 IDSTARAMU​】WE BACK HERE IN THE SPACE    BUT AT WHAT COST 【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
# この本ゲームは INNERSLOTH に確認を得た上で配信・収益化を行っております
#
# 【コラボメンバー COLLAB MEMBERS 】
#
# ◆AYUNDA RISU リス
# 【YOUTUBE】HTTPS   WWW YOUTUBE COM CHANNEL UCOYYB1C43VLX9RC LT6NKQW
# 【TWITTER】HTTPS   TWITTER COM AYUNDA RISU​
#
# ◆MOONA HOSHINOVA ムーナ
# 【YOUTUBE】HTTPS   WWW YOUTUBE COM CHANNEL UCP0BSPO AMEE3AQQQPO89DG
# 【TWITTER】HTTPS   TWITTER COM MOONAHOSHINOVA​
#
# ◆AIRANI IOFIFTEEN イオフィ
# 【YOUTUBE】HTTPS   WWW YOUTUBE COM CHANNEL UCAOY6RZHSF4YDCYJJW3WOVG​
# 【TWITTER】HTTPS   TWITTER COM AIRANIIOFIFTEEN​
#
# ◆KUREIJI OLLIE  オリー
# 【YOUTUBE】HTTPS   WWW YOUTUBE COM CHANNEL UCYZ 5N UDUCHHTLO7MY1HNQ
# 【TWITTER】HTTPS   TWITTER COM KUREIJIOLLIE​
#
# ◆PAVOLIA REINE  レイネ
# 【YOUTUBE】HTTPS   WWW YOUTUBE COM CHANNEL UCHGTYJG PDNVXXHDSXFHQ5Q​
# 【TWITTER】HTTPS   TWITTER COM PAVOLIAREINE​
#
# ◆アルランディス
# 【YOUTUBE】HTTPS   WWW YOUTUBE COM CHANNEL UCKEAHJVY8ZGXWBH9DUVJIAQ
# 【TWITTER】HTTPS   TWITTER COM ARURANDEISU​
#
# ◆影山シエン
# 【YOUTUBE】HTTPS   WWW YOUTUBE COM CHANNEL UCHSVPZYRPH0FVG4SJGSGA3G
# 【TWITTER】HTTPS   TWITTER COM KAGEYAMASHIEN​
#
# ◆荒咬オウガ
# 【YOUTUBE】HTTPS   WWW YOUTUBE COM CHANNEL UCWL7DGTXKO8Y4RFIKWAF8GA
# 【TWITTER】HTTPS   TWITTER COM ARAGAMIOGA​
#
# ◆夕刻ロベル
# 【YOUTUBE】HTTPS   WWW YOUTUBE COM CHANNEL UCANDOLYTJT7N5JLRC3ZFZVA
# 【TWITTER】HTTPS   TWITTER COM YUKOKUROBERU
#
#
#
# HOLOID X HOLOSTARS AMONG US COLLAB IS HEEEEEEEEEEEEERE  TWITTER TAG   IDSTARSAMU
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
# THUMBNAIL ARTS DRAWN BY  AIRANI IOFIFTEEN  AIRANIIOFIFTEEN
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-10 16:43:09+00:00
# 3
# 【A HAT IN TIME】SOME R A D HATS【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
# THIS GAME IS BEING STREAMED AND MONETIZED AFTER CONFIRMING WITH GEARS FOR BREAKFAST
#
#
# GIVE ME AAAAAAAAAAALL THE COOL HATS
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-07 18:37:39+00:00
# 0
# 【IB】超懐かしいゲームに再び挑戦してクリアまでやりたい【HOLOLIVE INDONESIA 2ND GENERATION】
# 本ゲームは  Ⓒ KOURI GUERTENA ART MUSEUM の確認を得た上で配信を行なっております
#
#
# クリアまでやれるのか…？！
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-06 10:26:35+00:00
# 6
# 【DEAD BY DAYLIGHT】WEEKEND EVENING MATCHING¿¿¿【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
# THIS GAME IS BEING STREAMED AND MONETIZED AFTER CONFIRMING WITH BEHAVIOUR INTERACTIVE INC
#
#
# DBD
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2021-02-05 09:51:04+00:00
# 5
# 【STIGMATIZED PROPERTY   事故物件】EVENING HORAGE【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE ドネーション↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
#
# THIS GAME IS BEING STREAMED AND MONETIZED AFTER RECEIVING PRIOR CONSENT FROM © CHILLA S ART  LLC
#
#
# THE DAYS OF TRYING TO ESCAPE THE HOBOLIVE LIFE RETURNS
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ...
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
# GREETINGS  AKU ANYA MELFISSA  SANG KERIS YANG SEKARANG MENJADI IDOL♪ LET’S ALL HAVE FUN TOGETHER
#  ANYA MELFISSA  LIVEISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID  ↓↓↓
# GENERASI
# 【AYUNDA RISU】
# • CHANNEL  HTTPS   T CO 3AI0D4VKBO AMP
# • TWITTER  HTTPS   TWITTER COM AYUNDA RISU
# 【MOONA HOSHINOVA】
# • CHANNEL  HTTPS   T CO W68ITCZBTG AMP
# • TWITTER  HTTPS   TWITTER COM MOONAHOSHINOVA
# 【AIRANI IOFIFTEEN】
# • CHANNEL  HTTPS   T CO ATHPGQEH2B AMP
# • TWITTER  HTTPS   TWITTER COM AIRANIIOFIFTEEN
#
# GENERASI
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2020-12-08 17:27:46+00:00
# 2
# READING DONATIONS   SOME TALKS ABOUT LIVETAG 【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
# GREETINGS  AKU ANYA MELFISSA  SANG KERIS YANG SEKARANG MENJADI IDOL♪ LET’S ALL HAVE FUN TOGETHER
#  ANYA MELFISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID 2ND GEN BABIES  ↓↓↓
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# • INSTAGRAM  HTTPS   INSTAGRAM COM KUREIJIOLLIE
# • FACEBOOK  HTTPS   WWW FACEBOOK COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
# • INSTAGRAM  HTTPS   INSTAGRAM COM PAVOLIAREINE
# • FACEBOOK  HTTPS   WWW FACEBOOK COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
#
# HTTPS   DOVA S JP
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2020-12-05 16:27:45+00:00
# 6
# POST DEBUT TALKS WITH OLLIE   HOLOLIVE S INDONESIA 2ND GENERATION
# SUPPORT ME HERE↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
# GREETINGS  AKU ANYA MELFISSA  SANG KERIS YANG SEKARANG MENJADI IDOL♪ LET’S ALL HAVE FUN TOGETHER
#  HOLOIDEBUT  ANYA MELFISSA
#
# COLLAB WITH KUREIJI OLLIE
# HTTPS   WWW YOUTUBE COM CHANNEL UCYZ 5N UDUCHHTLO7MY1HNQ
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID 2ND GEN BABIES  ↓↓↓
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# • INSTAGRAM  HTTPS   INSTAGRAM COM KUREIJIOLLIE
# • FACEBOOK  HTTPS   WWW FACEBOOK COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
# • INSTAGRAM  HTTPS   INSTAGRAM COM PAVOLIAREINE
# • FACEBOOK  HTTPS   WWW FACEBOOK COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
#
# HTTPS   DOVA S JP
#
#
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
# 2020-12-05 14:27:15+00:00
# 6
# 【DEBUT STREAM】UNSHEATHED  BUT STILL ASLEEP    【HOLOLIVE INDONESIA 2ND GENERATION】
# SUPPORT ME HERE↓
# HTTPS   STREAMLABS COM ANYAMELFISSACHHOLOLIVE ID TIP
#
# GREETINGS  AKU ANYA MELFISSA  SANG KERIS YANG SEKARANG MENJADI IDOL♪ LET’S ALL HAVE FUN TOGETHER
#  HOLOIDEBUT  ANYA MELFISSA
#
# 【ID】ATURAN YANG PERLU DIINGAT SAAT STREAMING SEDANG BERLANGSUNG
# • HARAP BERSIKAP BAIK DENGAN SESAMA PENONTON DAN BERKOMENTARLAH DENGAN BAHASA YANG SOPAN
# • DIMOHON UNTUK TIDAK MELAKUKAN DISKUSI DILUAR TOPIK PADA KOLOM KOMENTAR
# • DIMOHON TIDAK MELAKUKAN SPAM DALAM BENTUK APA PUN
# • DIMOHON UNTUK TIDAK MENGUMPAT  MENCELA  ATAU BERBICARA DENGAN BAHASA YANG KASAR
# • DIMOHON UNTUK JAGA SIKAP SAAT KOMENTAR DAN MOHON JANGAN KOMENTAR HAL HAL SENSITIF YANG BERBAU SARA  POLITIK  NSFW  DLL
# • DIMOHON UNTUK TIDAK BERDISKUSI SATU SAMA LAIN DI WAITING ROOM
# • DIMOHON UNTUK TIDAK MEMBERI KOMENTAR TENTANG VTUBER LAIN DI WAITING ROOM SAAT LIVESTREAM APABILA TIDAK DIMULAI LEBIH DULU OLEH VTUBER YANG SEDANG STREAMING KARENA BERSIFAT KURANG SOPAN
#
# 【EN】NOTICE DURING THE STREAM
# • PLEASE BE NICE WITH EACH OTHER AND COMMENT USING POLITE WORDS
# • PLEASE KEEP THE CHAT ON TOPIC IN RELATION TO THE STREAM
# • PLEASE DO NOT SPAM
# • PLEASE DO NOT SWEAR  BASH  OR TALK WITH ANY KIND OF FOUL LANGUAGE
# • PLEASE REFRAIN FROM COMMENTING ABOUT SENSITIVE TOPICS SUCH AS RACE  POLITICS  NSFW  ETC
# • PLEASE DO NOT DO ANY DISCUSSION IN THE WAITING ROOM
# • PLEASE DO NOT MENTION OR GIVE ANY COMMENT ABOUT OTHER VTUBER DURING THE LIVESTREAM IF THE TOPIC ISN T STARTED FIRST BY THE CURRENT STREAMER FIRST BECAUSE IT WOULD BE CONSIDERED IMPOLITE
#
# 【JP】皆に気を付けてほしいこと：
# ・視聴者同士で仲良く、丁寧な言葉でコメントをお願いします
# ・無関係の話題を話さないでください
# ・絵文字のスパムをしないようお願いします
# ・不適切な言葉を使わないでほしいです
# ・待機中の話を遠慮してほしいです
# ・話題に出ていない他の配信者について、話さないでください
#
# 【TWITTER】
# HTTPS   TWITTER COM ANYAMELFISSA
# 【INSTAGRAM】
# HTTPS   INSTAGRAM COM ANYAMELFISSA
# 【FACEBOOK PAGE】
# HTTPS   WWW FACEBOOK COM ANYAMELFISSA
#
# 【UEKURA EKU MAMA】
# • TWITTER  HTTPS   TWITTER COM EKUREEA
#
# 【SHIN UMIUSHI PAPA】
# • TWITTER  HTTPS   TWITTER COM SHIN UMIUSHI O
#
# ↓↓↓HOLOID 2ND GEN BABIES  ↓↓↓
# 【KUREIJI OLLIE】
# • CHANNEL  HTTPS   T CO VJ3JCQEGR3 AMP
# • TWITTER  HTTPS   TWITTER COM KUREIJIOLLIE
# • INSTAGRAM  HTTPS   INSTAGRAM COM KUREIJIOLLIE
# • FACEBOOK  HTTPS   WWW FACEBOOK COM KUREIJIOLLIE
# 【PAVOLIA REINE】
# • CHANNEL  HTTPS   T CO AKGZA8DGQF AMP
# • TWITTER  HTTPS   TWITTER COM PAVOLIAREINE
# • INSTAGRAM  HTTPS   INSTAGRAM COM PAVOLIAREINE
# • FACEBOOK  HTTPS   WWW FACEBOOK COM PAVOLIAREINE
#
# 【CREDITS】
# HTTPS   IRASUTOYA COM
# HTTP   WWW7B BIGLOBE NE JP  OSUMASHI
# HTTP   WWW FLICKR COM PHOTOS MERCEDESBENZENCINO   BY MERCEDES818  MODIFIED BY あやえも研究所  IS LICENSED UNDER A CREATIVE COMMONS LICENSE
# HTTP   CREATIVECOMMONS ORG LICENSES BY   DEED EN
# HTTPS   DOVA S JP
#
#
#
# 【OFFICIAL COVER WEBSITE】
# HTTP   COVER CORP COM
# 【OFFICIAL YOUTUBE CHANNEL HOLOLIVE INDONESIA】
# HTTPS   WWW YOUTUBE COM C HOLOLIVEINDONESIA
# 【OFFICIAL TWITTER HOLOLIVE INDONESIA】
# HTTPS   TWITTER COM HOLOLIVE ID
# 【OFFICIAL FACEBOOK HOLOLIVE INDONESIA】
# HTTPS   WWW FACEBOOK COM HOLOLIVE INDONESIA
#      hari jam  jami                                              judul  \
# 0       3  12     3  【AMONG US】WITH MEMBERS  FARMING  TIL I GET FUB...
# 1       2  16     3  【RAFT】HARDEST PLACE IN HARD   EASY SPEEDRUN【HO...
# 2       1  15     3  【RUST  ホロRUSTチーム戦】TEAM FIGHT WITH FULL ID【HOLO...
# 3       1  19     3  【AMONG US EN X ID COLLAB】MELFISSUS BUT ALSO ME...
# 4       6  06     1  【RUST】BACK TO THE    STONE AGE 【HOLOLIVE INDON...
# ..    ...  ..   ...                                                ...
# 411     2  18     3  【AMONG US】I TRUST NO ONE 【HOLOLIVE INDONESIA 2...
# 412     0  16     3  【日本語雑談】言葉遣いがまさに日本の現代オタクって言われがちみたいだけど実際はどうなん？【H...
# 413     3  17     3  READING DONATIONS   SOME TALKS ABOUT LIVETAG 【...
# 414     6  16     3  POST DEBUT TALKS WITH OLLIE   HOLOLIVE S INDON...
# 415     6  14     3  【DEBUT STREAM】UNSHEATHED  BUT STILL ASLEEP    ...
#
#              durasi                                               desc
# 0   0 days 02:23:56  SUPPORT ME HERE ドネーション↓\nSTREAMLABS  HTTPS   S...
# 1   0 days 03:42:27  SUPPORT ME HERE ドネーション↓\nSTREAMLABS  HTTPS   S...
# 2   0 days 03:10:28  SUPPORT ME HERE ドネーション↓\nSTREAMLABS  HTTPS   S...
# 3   0 days 02:20:12  COLLAB MEMBERS   MOONA HOSHINOVA HOLOLIVE ID  ...
# 4   0 days 04:46:50  SUPPORT ME HERE ドネーション↓\nSTREAMLABS  HTTPS   S...
# ..              ...                                                ...
# 411 0 days 01:57:23  SUPPORT ME HERE↓\nHTTPS   STREAMLABS COM ANYAM...
# 412 0 days 01:25:05  SUPPORT ME HERE ドネーション↓\nHTTPS   STREAMLABS CO...
# 413 0 days 01:49:01  SUPPORT ME HERE↓\nHTTPS   STREAMLABS COM ANYAM...
# 414 0 days 01:19:35  SUPPORT ME HERE↓\nHTTPS   STREAMLABS COM ANYAM...
# 415 0 days 01:12:24  SUPPORT ME HERE↓\nHTTPS   STREAMLABS COM ANYAM...
#
# [416 rows x 6 columns]
# [('2ND', 409), ('GENERATION】', 384), ('INDONESIA', 332), ('【HOLOLIVE', 158), ('THE', 67), ('S', 49), ('ID', 48), ('A', 39), ('TO', 35), ('OF', 29)]
#       jam  jami  judul  durasi  desc
# hari
# 0      55    55     55      55    55
# 1      37    37     37      37    37
# 2      42    42     42      42    42
# 3      65    65     65      65    65
# 4      65    65     65      65    65
# 5      76    76     76      76    76
# 6      76    76     76      76    76
#      hari  jami  judul  durasi  desc
# jam
# 00      7     7      7       7     7
# 01      4     4      4       4     4
# 02      7     7      7       7     7
# 03     10    10     10      10    10
# 04      8     8      8       8     8
# 05      6     6      6       6     6
# 06      4     4      4       4     4
# 07      9     9      9       9     9
# 08      6     6      6       6     6
# 09     15    15     15      15    15
# 10     16    16     16      16    16
# 11     10    10     10      10    10
# 12      9     9      9       9     9
# 13      4     4      4       4     4
# 14     25    25     25      25    25
# 15     43    43     43      43    43
# 16     73    73     73      73    73
# 17     60    60     60      60    60
# 18     44    44     44      44    44
# 19     32    32     32      32    32
# 20     11    11     11      11    11
# 21     11    11     11      11    11
# 22      1     1      1       1     1
# 23      1     1      1       1     1
#       jam  jami  judul  durasi  desc
# hari
# 0      55    55     55      55    55
# 1      37    37     37      37    37
# 2      42    42     42      42    42
# 3      65    65     65      65    65
# 4      65    65     65      65    65
# 5      76    76     76      76    76
# 6      76    76     76      76    76
#       hari  jam  judul  durasi  desc
# jami
# 1       55   55     55      55    55
# 3      361  361    361     361   361
# 0 days 02:53:25.026442307
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:131: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.median(level=1) should use df.groupby(level=1).median().
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:132: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.median(level=1) should use df.groupby(level=1).median().
